# %%
import os
import streamlit as st
import pickle
import time
import faiss
import numpy as np
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from sentence_transformers import SentenceTransformer
from transformers import pipeline, AutoModelForSeq2SeqLM, AutoTokenizer

# Constants
FILE_PATH = "faiss_store.pkl"

st.title("RockyBot: News Research Tool 📈")
st.sidebar.title("News Article URLs")

# User Input: Dynamic URL Entry
urls = st.sidebar.text_area("Enter article URLs (one per line)").split("\n")
process_url_clicked = st.sidebar.button("Process URLs")

# Load Hugging Face LLM (Replaces OpenAI)
@st.cache_resource
def load_llm():
    model_name = "google/flan-t5-base"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
    return pipeline("text2text-generation", model=model, tokenizer=tokenizer)

# Load Sentence Transformer model for embeddings
@st.cache_resource
def load_embedding_model():
    return SentenceTransformer("all-MiniLM-L6-v2")

# Process URLs and store FAISS index
def process_urls(urls, embedding_model):
    if not any(urls):
        st.error("Please enter at least one valid URL.")
        return

    try:
        st.text("Fetching articles... ⏳")
        loader = UnstructuredURLLoader(urls=urls)
        data = loader.load()

        st.text("Splitting text into chunks... ⏳")
        text_splitter = RecursiveCharacterTextSplitter(separators=['\n\n', '\n', '.', ','], chunk_size=1000)
        docs = text_splitter.split_documents(data)

        st.text("Generating embeddings... ⏳")
        embeddings = np.array([embedding_model.encode(doc.page_content) for doc in docs])

        index = faiss.IndexFlatL2(embeddings.shape[1])
        index.add(embeddings)

        with open(FILE_PATH, "wb") as f:
            pickle.dump((index, docs), f)

        st.text("Processing complete! ✅")
        time.sleep(2)

    except ModuleNotFoundError:
        st.error("Missing dependencies. Install using:")
        st.code("pip install unstructured pdfminer.six unstructured-inference unstructured-pytesseract")
    except Exception as e:
        st.error(f"Error processing URLs: {e}")

# Retrieve answers from FAISS
def query_llm(question, generator, embedding_model):
    if not os.path.exists(FILE_PATH):
        return "No data available. Please process URLs first."

    try:
        with open(FILE_PATH, "rb") as f:
            index, docs = pickle.load(f)

        question_embedding = embedding_model.encode(question).reshape(1, -1)
        D, I = index.search(question_embedding, k=3)

        relevant_texts = " ".join([docs[i].page_content for i in I[0]])

        prompt = f"Context: {relevant_texts}\n\nQuestion: {question} Answer:"
        response = generator(prompt, max_length=200, do_sample=True)

        return response[0]['generated_text']

    except FileNotFoundError:
        return "Error: FAISS index not found. Please process URLs first."
    except Exception as e:
        return f"Error: {str(e)}"

# Load models
generator = load_llm()
embedding_model = load_embedding_model()

# Process URLs
if process_url_clicked:
    process_urls(urls, embedding_model)

# Question Input
query = st.text_input("Ask a question:")
if query:
    answer = query_llm(query, generator, embedding_model)
    st.subheader("Answer:")
    st.write(answer)
# Out:
# 2025-02-25 16:06:50.476
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\rgurr\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-02-25 16:06:50.495 Session state does not function when running a script without `streamlit run`
# Device set to use cpu

# %%
pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.10.0-cp312-cp312-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\rgurr\anaconda3\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\rgurr\anaconda3\lib\site-packages (from faiss-cpu) (24.1)
# Using cached faiss_cpu-1.10.0-cp312-cp312-win_amd64.whl (13.7 MB)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade streamlit transformers sentence-transformers faiss-cpu langchain unstructured pdfminer.six unstructured-inference unstructured-pytesseract
# Out:
# Requirement already satisfied: streamlit in c:\users\rgurr\anaconda3\lib\site-packages (1.37.1)
# Collecting streamlit
#   Downloading streamlit-1.42.2-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting transformers
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# Collecting sentence-transformers
#   Using cached sentence_transformers-3.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: faiss-cpu in c:\users\rgurr\anaconda3\lib\site-packages (1.10.0)
# Collecting langchain
#   Using cached langchain-0.3.19-py3-none-any.whl.metadata (7.9 kB)
# Collecting unstructured
#   Using cached unstructured-0.16.23-py3-none-any.whl.metadata (24 kB)
# Collecting pdfminer.six
#   Using cached pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Collecting unstructured-inference
#   Using cached unstructured_inference-0.8.7-py3-none-any.whl.metadata (5.3 kB)
# Collecting unstructured-pytesseract
#   Using cached unstructured.pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\rgurr\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: filelock in c:\users\rgurr\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.26.0 (from transformers)
#   Using cached huggingface_hub-0.29.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rgurr\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\rgurr\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.5.2-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\rgurr\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.6.0-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: scikit-learn in c:\users\rgurr\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\rgurr\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Collecting langchain-core<1.0.0,>=0.3.35 (from langchain)
#   Using cached langchain_core-0.3.39-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6 (from langchain)
#   Using cached langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.11-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain) (3.10.5)
# Requirement already satisfied: chardet in c:\users\rgurr\anaconda3\lib\site-packages (from unstructured) (4.0.0)
# Collecting filetype (from unstructured)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in c:\users\rgurr\anaconda3\lib\site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in c:\users\rgurr\anaconda3\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\rgurr\anaconda3\lib\site-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured)
#   Using cached python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Using cached langdetect-1.0.9-py3-none-any.whl
# Collecting rapidfuzz (from unstructured)
#   Using cached rapidfuzz-3.12.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting backoff (from unstructured)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting unstructured-client (from unstructured)
#   Using cached unstructured_client-0.30.4-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: wrapt in c:\users\rgurr\anaconda3\lib\site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: psutil in c:\users\rgurr\anaconda3\lib\site-packages (from unstructured) (5.9.0)
# Collecting python-oxmsg (from unstructured)
#   Using cached python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\rgurr\anaconda3\lib\site-packages (from pdfminer.six) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\rgurr\anaconda3\lib\site-packages (from pdfminer.six) (43.0.0)
# Collecting python-multipart (from unstructured-inference)
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting opencv-python!=4.7.0.68 (from unstructured-inference)
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting onnx (from unstructured-inference)
#   Downloading onnx-1.17.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting onnxruntime>=1.17.0 (from unstructured-inference)
#   Downloading onnxruntime-1.20.1-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Requirement already satisfied: matplotlib in c:\users\rgurr\anaconda3\lib\site-packages (from unstructured-inference) (3.9.2)
# Collecting timm (from unstructured-inference)
#   Using cached timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# Collecting pypdfium2 (from unstructured-inference)
#   Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.0)
# Requirement already satisfied: jinja2 in c:\users\rgurr\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\rgurr\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\rgurr\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\rgurr\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\rgurr\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\rgurr\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rgurr\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.6.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.35->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rgurr\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.0)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.17->langchain)
#   Using cached orjson-3.10.15-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\rgurr\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\rgurr\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Collecting coloredlogs (from onnxruntime>=1.17.0->unstructured-inference)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.17.0->unstructured-inference)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: sympy in c:\users\rgurr\anaconda3\lib\site-packages (from onnxruntime>=1.17.0->unstructured-inference) (1.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rgurr\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rgurr\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rgurr\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rgurr\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rgurr\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rgurr\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rgurr\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rgurr\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rgurr\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rgurr\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rgurr\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: networkx in c:\users\rgurr\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: setuptools in c:\users\rgurr\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Collecting sympy (from onnxruntime>=1.17.0->unstructured-inference)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rgurr\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rgurr\anaconda3\lib\site-packages (from beautifulsoup4->unstructured) (2.5)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.9 in c:\users\rgurr\anaconda3\lib\site-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\rgurr\anaconda3\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rgurr\anaconda3\lib\site-packages (from matplotlib->unstructured-inference) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rgurr\anaconda3\lib\site-packages (from matplotlib->unstructured-inference) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rgurr\anaconda3\lib\site-packages (from matplotlib->unstructured-inference) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rgurr\anaconda3\lib\site-packages (from matplotlib->unstructured-inference) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rgurr\anaconda3\lib\site-packages (from matplotlib->unstructured-inference) (3.1.2)
# Requirement already satisfied: joblib in c:\users\rgurr\anaconda3\lib\site-packages (from nltk->unstructured) (1.4.2)
# Collecting olefile (from python-oxmsg->unstructured)
#   Using cached olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rgurr\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Collecting torchvision (from timm->unstructured-inference)
#   Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting eval-type-backport>=0.2.0 (from unstructured-client->unstructured)
#   Using cached eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\rgurr\anaconda3\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Using cached pypdf-5.3.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.27.2-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions<5,>=4.4.0 (from streamlit)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pycparser in c:\users\rgurr\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\rgurr\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: anyio in c:\users\rgurr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\rgurr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\rgurr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rgurr\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rgurr\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rgurr\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.35->langchain) (2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rgurr\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rgurr\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rgurr\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rgurr\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rgurr\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.17.0->unstructured-inference)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading streamlit-1.42.2-py2.py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 1.5 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.6 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.6 MB 1.8 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.6 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.6 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.6 MB 2.3 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.6 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.6 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.6 MB 2.8 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.6 MB 2.9 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.6 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 3.4 MB/s eta 0:00:00
# Using cached transformers-4.49.0-py3-none-any.whl (10.0 MB)
# Using cached sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
# Using cached langchain-0.3.19-py3-none-any.whl (1.0 MB)
# Using cached unstructured-0.16.23-py3-none-any.whl (1.8 MB)
# Using cached pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
# Using cached unstructured_inference-0.8.7-py3-none-any.whl (48 kB)
# Using cached unstructured.pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Using cached huggingface_hub-0.29.1-py3-none-any.whl (468 kB)
# Using cached langchain_core-0.3.39-py3-none-any.whl (414 kB)
# Using cached langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Downloading langsmith-0.3.11-py3-none-any.whl (335 kB)
# Downloading onnxruntime-1.20.1-cp312-cp312-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.3 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.3 MB 6.1 MB/s eta 0:00:02
#    ------------ --------------------------- 3.7/11.3 MB 6.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.3 MB 6.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.3 MB 6.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.1/11.3 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.3 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 6.7 MB/s eta 0:00:00
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Using cached safetensors-0.5.2-cp38-abi3-win_amd64.whl (303 kB)
# Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
# Using cached torch-2.6.0-cp312-cp312-win_amd64.whl (204.1 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached emoji-2.14.1-py3-none-any.whl (590 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading onnx-1.17.0-cp312-cp312-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/14.5 MB 7.6 MB/s eta 0:00:02
#    --------- ------------------------------ 3.4/14.5 MB 8.0 MB/s eta 0:00:02
#    -------------- ------------------------- 5.2/14.5 MB 8.4 MB/s eta 0:00:02
#    ------------------- -------------------- 7.1/14.5 MB 8.4 MB/s eta 0:00:01
#    ------------------------ --------------- 8.9/14.5 MB 8.3 MB/s eta 0:00:01
#    ------------------------------ --------- 11.0/14.5 MB 8.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.8/14.5 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 14.5/14.5 MB 8.5 MB/s eta 0:00:00
# Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl (3.0 MB)
# Using cached python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Using cached python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Using cached rapidfuzz-3.12.1-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached timm-1.0.15-py3-none-any.whl (2.4 MB)
# Using cached unstructured_client-0.30.4-py3-none-any.whl (164 kB)
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Using cached eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached orjson-3.10.15-cp312-cp312-win_amd64.whl (133 kB)
# Using cached pypdf-5.3.0-py3-none-any.whl (300 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached olefile-0.47-py2.py3-none-any.whl (114 kB)
# Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl (1.6 MB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: flatbuffers, filetype, unstructured-pytesseract, typing-extensions, sympy, safetensors, rapidfuzz, python-multipart, python-magic, python-iso639, pyreadline3, pypdfium2, pypdf, orjson, opencv-python, onnx, olefile, marshmallow, langdetect, html5lib, eval-type-backport, emoji, backoff, aiofiles, typing-inspect, torch, python-oxmsg, pydantic-core, humanfriendly, huggingface-hub, torchvision, tokenizers, pydantic, pdfminer.six, dataclasses-json, coloredlogs, unstructured-client, transformers, timm, onnxruntime, langsmith, unstructured-inference, unstructured, streamlit, sentence-transformers, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.37.1
#     Uninstalling streamlit-1.37.1:
#       Successfully uninstalled streamlit-1.37.1
# Successfully installed aiofiles-24.1.0 backoff-2.2.1 coloredlogs-15.0.1 dataclasses-json-0.6.7 emoji-2.14.1 eval-type-backport-0.2.2 filetype-1.2.0 flatbuffers-25.2.10 html5lib-1.1 huggingface-hub-0.29.1 humanfriendly-10.0 langchain-0.3.19 langchain-core-0.3.39 langchain-text-splitters-0.3.6 langdetect-1.0.9 langsmith-0.3.11 marshmallow-3.26.1 olefile-0.47 onnx-1.17.0 onnxruntime-1.20.1 opencv-python-4.11.0.86 orjson-3.10.15 pdfminer.six-20240706 pydantic-2.10.6 pydantic-core-2.27.2 pypdf-5.3.0 pypdfium2-4.30.1 pyreadline3-3.5.4 python-iso639-2025.2.18 python-magic-0.4.27 python-multipart-0.0.20 python-oxmsg-0.0.2 rapidfuzz-3.12.1 safetensors-0.5.2 sentence-transformers-3.4.1 streamlit-1.42.2 sympy-1.13.1 timm-1.0.15 tokenizers-0.21.0 torch-2.6.0 torchvision-0.21.0 transformers-4.49.0 typing-extensions-4.12.2 typing-inspect-0.9.0 unstructured-0.16.23 unstructured-client-0.30.4 unstructured-inference-0.8.7 unstructured-pytesseract-0.3.13
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.3.18-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.37 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (0.3.39)
# Requirement already satisfied: langchain<1.0.0,>=0.3.19 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (0.3.19)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Using cached pydantic_settings-2.8.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (0.3.11)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rgurr\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\rgurr\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\rgurr\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\rgurr\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rgurr\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\rgurr\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\rgurr\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\rgurr\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\rgurr\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rgurr\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rgurr\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rgurr\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rgurr\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rgurr\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\rgurr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\rgurr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\rgurr\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rgurr\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rgurr\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.37->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rgurr\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\rgurr\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rgurr\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Using cached langchain_community-0.3.18-py3-none-any.whl (2.5 MB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Using cached pydantic_settings-2.8.0-py3-none-any.whl (30 kB)
# Installing collected packages: httpx-sse, pydantic-settings, langchain-community
# Successfully installed httpx-sse-0.4.0 langchain-community-0.3.18 pydantic-settings-2.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run main.py
# Out:
# ^C
